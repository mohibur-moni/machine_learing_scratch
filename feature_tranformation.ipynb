# %%
import pandas as pd
df = pd.read_csv('agora.csv')
df.describe()
df.head()

# %%
# Features Transformation Normalization
from sklearn.preprocessing import MinMaxScaler

m = MinMaxScaler()
markrting_speed_fit  = m.fit(df[['Marketing Spend']]) # trianing model 

df['transformed'] = m.transform(df[['Marketing Spend']]) # transferred to data frame

# %%
m_ = MinMaxScaler(feature_range=(5,10))
markrting_speed_fit_  = m_.fit(df[['Marketing Spend']]) 

df['transformed_2'] = m_.transform(df[['Marketing Spend']])
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Marketing Spend</th>
#       <th>Administration</th>
#       <th>Transport</th>
#       <th>Area</th>
#       <th>Profit</th>
#       <th>transformed</th>
#       <th>transformed_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>114523.61</td>
#       <td>136897.80</td>
#       <td>471784.10</td>
#       <td>Dhaka</td>
#       <td>192261.83</td>
#       <td>0.692617</td>
#       <td>8.463083</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>162597.70</td>
#       <td>151377.59</td>
#       <td>443898.53</td>
#       <td>Ctg</td>
#       <td>191792.06</td>
# ...

# %%
import numpy as np

d = np.linspace(1, 10000, num = 10000, axis=0)

ad_fit_admimistration = m_.fit_transform(df[['Administration']])

ad_fit_admimistration
# Out:
# (10000,)

# %%
# Features Transformation Standarization
from sklearn.preprocessing import StandardScaler

s_s = StandardScaler()

# %%
s_s_1 = s_s.fit_transform(df[['Marketing Spend']]) # combined 

s_s_1
# Out:
# <pre>array([[ 0.89791312],
#        [ 1.95586034],
#        [ 1.75436374],
#        [ 1.55478369],
#        [ 1.5049372 ],
#        [ 1.27980001],
#        [ 1.34006641],
#        [ 1.24505666],
#        [ 1.03036886],
#        [ 1.09181921],
#        [ 0.62039825],
#        [ 0.59308542],
#        [ 0.44325987],
#        [ 0.4020776 ],
#        [ 1.01718075],
#        [ 2.01641149],
#        [ 0.0944412 ],
#        [ 0.46072013],
#        [ 0.39672494],
#        [ 0.27944165],
#        [ 0.05572609],
#        [ 0.1027236 ],
#        [ 0.00600658],
#        [-0.13620072],
#        [ 0.0731146 ],
#        [-0.19931169],
#        [ 0.0353702 ],
#        [-0.03551899],
#        [-0.16879272],
#        [-0.17860854],
#        [-0.25807437],
#        [-0.27695823],
#        [-0.22694868],
#        [-0.40112892],
#        [-0.60068212],
#        [-0.60974994],
#        [-0.99157015],
#        [-0.65253231],
#        [-1.17717755],
#        [-0.77382036],
#        [-0.98957702],
# ...

# %%
# Features Transformation Robust Scaler
from sklearn.preprocessing import RobustScaler

r_b = RobustScaler()

r_b_0 = r_b.fit_transform(df[['Marketing Spend']])
r_b_0
# Out:
# <pre>array([[ 0.67253009],
#        [ 1.45211292],
#        [ 1.3036336 ],
#        [ 1.15656655],
#        [ 1.11983554],
#        [ 0.95393588],
#        [ 0.99834513],
#        [ 0.9283341 ],
#        [ 0.77013442],
#        [ 0.8154161 ],
#        [ 0.46803423],
#        [ 0.44790788],
#        [ 0.33750405],
#        [ 0.30715756],
#        [ 0.76041632],
#        [ 1.49673201],
#        [ 0.08046566],
#        [ 0.35037021],
#        [ 0.30321327],
#        [ 0.21678926],
#        [ 0.05193717],
#        [ 0.08656882],
#        [ 0.01529973],
#        [-0.08949034],
#        [ 0.06475046],
#        [-0.13599571],
#        [ 0.03693728],
#        [-0.01529973],
#        [-0.11350681],
#        [-0.12073992],
#        [-0.1792969 ],
#        [-0.19321209],
#        [-0.15636092],
#        [-0.28471131],
#        [-0.43175858],
#        [-0.43844049],
#        [-0.71979714],
#        [-0.46996607],
#        [-0.85656799],
#        [-0.55934112],
#        [-0.71832843],
# ...

# %%
# Features Transformation MaxAbsolute
from sklearn.preprocessing import MaxAbsScaler

m_a_s = MaxAbsScaler()

m_a_s_0 = m_a_s.fit_transform(df[['Marketing Spend']])

m_a_s_0
# Out:
# <pre>array([[0.69261666],
#        [0.98335946],
#        [0.92798459],
#        [0.87313643],
#        [0.85943772],
#        [0.797566  ],
#        [0.81412828],
#        [0.7880179 ],
#        [0.72901786],
#        [0.74590551],
#        [0.61635061],
#        [0.60884455],
#        [0.56766982],
#        [0.55635219],
#        [0.72539353],
#        [1.        ],
#        [0.47180821],
#        [0.57246821],
#        [0.55488118],
#        [0.52264964],
#        [0.46116861],
#        [0.47408436],
#        [0.4475048 ],
#        [0.40842369],
#        [0.46594728],
#        [0.39107967],
#        [0.45557444],
#        [0.43609283],
#        [0.39946683],
#        [0.39676926],
#        [0.37493063],
#        [0.36974101],
#        [0.38348453],
#        [0.33561668],
#        [0.2807759 ],
#        [0.2782839 ],
#        [0.17335288],
#        [0.26652654],
#        [0.12234465],
#        [0.23319442],
#        [0.17390063],
#        [0.16869099],
#        [0.14297577],
# ...
